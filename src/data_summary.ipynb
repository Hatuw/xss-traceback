# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

DATA_DIR = '../data'
DATA_FILE = 'mirror.csv'
DATA_FILE = 'xss.csv'

data_file = os.path.join(DATA_DIR, DATA_FILE)

# %%
data = pd.read_csv(data_file)
data.head()
# Out:
#   Datesubmitted Datepublished   Status           Author  \
# 0    18/08/2014    13/03/2015  UNFIXED   SquirrelBuddha
# 1    05/01/2014    13/03/2015    FIXED          puritys
# 2    15/11/2013    13/03/2015    FIXED     ArianaGrande
# 3    06/10/2014    13/03/2015  UNFIXED         MrCyph3r
# 4    09/08/2012    13/03/2015    FIXED  FabianCuchietti
#
#                                Domain Category  Pagerank  \
# 0  webcenters.netscape.compuserve.com      XSS     70880
# 1                   store.samsung.com      XSS       340
# 2                        auth.dhs.gov      XSS      4057
# 3                   www.titivillus.it      XSS  11882046
# 4                    www.brazzers.com      XSS      1755
#
#                                                  URL
# 0  http://webcenters.netscape.compuserve.com/weat...
# 1  http://store.samsung.com/uk/camera/smart-n2x">...
# 2  https://auth.dhs.gov/oam/hsinlogin/?authn_try_...
# 3  http://www.titivillus.it/periodico.php?id=15%3...
# 4  http://www.brazzers.com/series/view/episodes/%...

# %%
# pagerank distribution
# data['Pagerank'].hist(bins=30)
import numpy as np
log_pr = np.log(data[data['Pagerank'] != 0]['Pagerank'])
# plt.hist(data['Pagerank'], bins=30, log=True, )
plt.hist(log_pr, bins=30, log=True )
plt.xlabel("$log_e PR$")
plt.ylabel("Count")
plt.grid()
plt.show()

# %%
from collections import Counter, OrderedDict
ct_result = dict(Counter(data['Author']))
ct_result
# Out:
# {'SquirrelBuddha': 1,
#  'puritys': 1,
#  'ArianaGrande': 1,
#  'MrCyph3r': 1,
#  'FabianCuchietti': 41,
#  '03storic': 28,
#  'C37HUN': 2,
#  'NicholasLemonias': 1,
#  'M4D3RS': 1,
#  'Anonymous': 62,
#  'Keeper': 1,
#  'RedToor': 1,
#  'tig3rhack': 1,
#  '0x73F': 1,
#  'Vajra': 1,
#  'little': 1,
#  'p0pc0rn': 286,
#  'AarshitMittal': 6,
#  'Flux': 1,
#  'warvector': 148,
#  'DigitalBoysUnderground': 1,
#  'OrionEinfold': 1,
#  'cyb3r.pr3dat0r': 1,
#  'Uber0n': 2064,
#  'WIBF': 1,
#  'raVen': 1,
#  'M4ke': 1,
#  'rstforums': 1,
#  'haRI': 60,
#  'necromoine': 3,
#  'IrIsT.Ir': 97,
#  'flexxpoint': 64,
#  'Bl3ck0uT': 1,
#  'Atmon3r': 480,
#  'wutsec': 18,
#  'Cr4t3r': 15,
#  'owege': 18,
#  'UR0B0R0X': 4,
#  'worldwideweb': 1,
#  'az7rb': 2,
#  'n0caReTeAm': 1,
#  'Conslight': 1,
#  'AnonGuy': 1,
#  '0z0n3': 1,
#  'Sony': 273,
#  'bastich': 22,
#  'crucki': 19,
#  'Xermes': 1,
#  'CyberBellona': 25,
#  'IsmailSaygili': 1,
#  'v30sharp': 1,
#  'anon': 2,
#  'MatiasVicente': 29,
#  'Mr.JurisT': 20,
#  'ZhcPoint': 2,
#  'x1337Sec': 1,
#  'cyber3vil': 1,
#  'Tux1': 1,
#  'frite': 1,
#  'CMD': 8,
#  'bujabaes': 1,
#  'krusch': 6,
#  'Netxing': 3,
#  'DevaDraco': 1,
#  'SaifuddinAmri': 1,
#  'EhsanIce': 2,
#  'cyber-71': 1,
#  'k0gs1n': 1,
#  'r14nul': 3,
#  'longrifle0x': 38,
#  'joker_s': 39,
#  'a3q': 14,
#  '28C3': 4,
#  's3m00t': 11,
#  '4g3n71337': 1,
#  'fubar': 2,
#  'homeostasieftp3lo': 1,
#  'Mystick': 824,
#  'AudisoftHackerTeam': 1,
#  'mygot_manoel': 175,
#  'XSSLotion': 33,
#  'holisticinfosec': 258,
#  'matt0': 5,
#  'VipulAgarwal': 7,
#  'toxbot': 1,
#  'm4x': 20,
#  'Viper.aT': 278,
#  'Hexspirit': 96,
#  'RME': 8,
#  'dhony': 1,
#  'Jamaicob': 5,
#  's1ckb0y': 1,
#  'AnonHiV3MinD': 1,
#  'SouhailHammou': 1,
#  'StRoNiX': 3,
#  'ThePr0ph3t': 1,
#  'ZargarYasir': 1,
#  'MaxGovanni': 1,
#  'EdgardChammas': 7,
#  'thexugj': 1,
#  'ShahinRamezany': 1,
#  'ZyrgEr': 1,
#  'yourfullname': 1,
#  'Troy': 1,
#  'n93n93k': 2,
#  'Leyli_Liv': 1,
#  'd@ydream': 1,
#  'RobertK': 1,
#  'PlanetCreator': 45,
#  'Xartrick': 20,
#  'rsb': 1,
#  'Atm0n3r': 1,
#  '0c001': 1,
#  'ChristyPhilipMathew': 1,
#  'Cyb3R_Shubh4M': 2,
#  '0xAli': 2,
#  'TalentedFool': 1,
#  'shellc0de': 3,
#  'ant4g0nist': 1,
#  'NetFuzzer': 24,
#  'Xylitol': 468,
#  'OXO': 1,
#  'SquirmyBeast': 1,
#  'Killer-TR': 61,
#  'ALPACAHACK.COM': 13,
#  'r007k17-w': 11,
#  'rVk': 2,
#  'esteban22x': 1,
#  'keyrox': 1,
#  'XSSh0BBy': 2,
#  'watt': 77,
#  'VijayendraNigam': 54,
#  'Droid': 11,
#  'd3v1l': 102,
#  'EuropaFan': 2,
#  'loverboy': 1,
#  'INTHackers': 1,
#  'LeetSecurity': 1,
#  'pimpim': 52,
#  's3rver.exe': 2,
#  'Msk': 5,
#  'xssh0bby': 11,
#  'Batch': 29,
#  'LohitTummalapenta': 3,
#  'MaKyOtOx': 2,
#  'alanh0': 1,
#  'flexx': 1,
#  'XPEHOTAC': 8,
#  'Mr.PaPaRoSSe': 2,
#  '04hrb': 1,
#  'Mr.ThieF': 1,
#  'r007k17': 5,
#  'AustinHartzheim': 1,
#  'BlackHatGroup': 1,
#  'AR3SW0RMED': 170,
#  '0x6834636b': 4,
#  'alkolkafayapar': 1,
#  'sheshDv1p3r': 2,
#  'Megabyte': 2,
#  'Ryuzaki': 3,
#  'BlackLorD': 1,
#  'n4pst3r': 4,
#  'EjRaM-HaCkEr': 1,
#  'SOLVER': 1,
#  'xCero': 1,
#  'SeeMe': 177,
#  'F0lk3n': 2,
#  'soaj1664ashar': 1,
#  'ebanyu': 1,
#  'hac4ker': 3,
#  'mghack': 26,
#  'TheLegend': 8,
#  'Virtual_SystEm': 88,
#  'sh3n': 28,
#  'AKABEY': 4,
#  'Securitylab.ir': 36,
#  'BigBear': 1,
#  'Takpar': 1,
#  'Gm.Sys': 1,
#  'hexon': 29,
#  'WongChiehYie': 53,
#  'RoLex': 7,
#  'd3vbit3': 65,
#  'PaPPy': 882,
#  'nullbyt3': 116,
#  'Th3RDX': 40,
#  'AndMyXSS': 21,
#  'Yeyah': 23,
#  'X3R0': 19,
#  'Xorphem': 1,
#  'sangteamtham': 1,
#  'Juza': 51,
#  'Timse': 11,
#  'b4dsect0r': 2,
#  'RoAd_KiLlEr': 12,
#  'Idahc': 4,
#  'haRi': 2,
#  'RohitBansal': 47,
#  'internet': 26,
#  'KalleHoppe': 1,
#  'benzo': 1,
#  'www.phtzone.net': 11,
#  'F0RTYS3V3N': 6,
#  'soldier': 2,
#  'SH4V': 8,
#  'l3d': 37,
#  'CalloGsK2': 40,
#  'PyskE': 19,
#  'Rivijx7k0s': 6,
#  'sEtH': 1,
#  'Airrox': 67,
#  'centrinel': 4,
#  'secrgb': 11,
#  '599emeMan': 49,
#  'bl4ck': 1,
#  'lithium9': 14,
#  'warvectordu': 1,
#  'TreX': 559,
#  'www.pastebin.im': 1,
#  'nameless': 3,
#  'splogger': 5,
#  'skathgh420': 179,
#  'jath': 151,
#  'Ravac': 84,
#  'KurtisDinelle': 1,
#  'Dark.Man': 219,
#  'VinayKatoch': 35,
#  nan: 1,
#  'siD3_effectS': 2,
#  'XaDoS': 55,
#  'Cheops': 1,
#  'LostBrilliance': 45,
#  'TurKPoweR': 369,
#  'Willis': 1,
#  'Skyr3x': 37,
#  'Rugburn': 55,
#  'W4R3Z-FedericoC.diHackshare': 1,
#  'illuz1oN': 7,
#  'ironzorg': 203,
#  'Methodman': 27,
#  'ThR0ad': 5,
#  'tenest': 541,
#  'Yacin': 1,
#  't3hmadhatt3r': 1,
#  'Agd_Scorp': 42,
#  'gaussillusion': 1,
#  'black.spook': 1,
#  'ProLaAnhCR': 1,
#  'Anshulkatta': 1,
#  'BoxHead': 1,
#  'strohhalm': 9,
#  'HimanshuKumarDas': 1,
#  'Felipower': 1,
#  'sepyanser': 1,
#  'deserT': 1,
#  'EduardoAbril': 2,
#  'str0nge': 1,
#  'xwungu': 7,
#  'Vaibs': 2,
#  'C4prica': 2,
#  'WwW.TRLink.NET': 2,
#  'mckt': 314,
#  'BHG': 2,
#  'Jester': 3,
#  'WTCLeGeND': 3,
#  'E1': 2,
#  'Cface': 1,
#  'memon': 3,
#  'simone': 1,
#  'BlueMax': 149,
#  '3niGma': 8,
#  '44414E.15': 2,
#  'WaR': 1,
#  'Zeitjak': 104,
#  'Python5': 327,
#  'Reflequillinn': 1,
#  'pgardenat': 4,
#  'Sil3nt4rmyCr3w': 1,
#  'Dr.Optix': 96,
#  'MrDoug': 10,
#  'l.g': 3,
#  'MuhammadHaroon': 1,
#  'DaiMon': 207,
#  'JJFourOneOne': 1,
#  'J-Hacker': 1,
#  'NileshSubmissionforOpenRedirect': 1,
#  'ResisTance': 30,
#  'sl4xUz': 473,
#  'hades': 12,
#  'hack4011': 1,
#  'p3lo': 47,
#  'C1c4Tr1Z': 308,
#  'DraKuLa': 26,
#  'ZombiE_KsA': 3,
#  'megaturks': 1,
#  'agix': 1,
#  'z9': 6,
#  'rusnaka': 1,
#  'Woo': 50,
#  'bho': 63,
#  'wingb0t': 3,
#  'kerzua': 5,
#  'st@rext': 278,
#  'Fugitif': 108,
#  'FdumanLi': 1,
#  'Codeshift3r': 70,
#  'Fzero': 16,
#  'Smegol': 1,
#  'PirateAL': 1,
#  'JulienDev': 1,
#  'T3': 1,
#  'autoexectrojan': 1,
#  'tr4st': 1,
#  'aSU_aBANG': 16,
#  'BHGSecurityCenter': 1,
#  'OmegaAp3x': 6,
#  'JonStockton': 38,
#  'ZxX': 3,
#  'GirishShrimali': 2,
#  'Nob0dy': 1,
#  'slake': 6,
#  'HaxInTheBox.BlogSpot.com': 2,
#  'zer0flag': 4,
#  'S_e_YM_e_N': 209,
#  'BugReport.ir': 4,
#  'Kara': 10,
#  'xDarkSton3x': 3,
#  'linux-dz': 6,
#  'Italiano': 1,
#  'PrashantUniyal': 35,
#  'CoMPLEX': 28,
#  'warjryn': 3,
#  'Rianul': 1,
#  'DialogitecImeCiQ': 34,
#  'HediMlika': 1,
#  'Olli': 1,
#  'Jurpie': 23,
#  'HaxOr': 3,
#  'rianul': 1,
#  'Trueliarx': 20,
#  'samir-dz': 1,
#  'PredragCujanovic': 4,
#  'delirium': 1,
#  'lolh4x': 3,
#  'E400': 1,
#  'CTFG': 1,
#  'RemoteExecution': 14,
#  'Scorp': 3,
#  'Pulkit': 1,
#  '3spi0n': 6,
#  'EBRSecurity': 1,
#  'Javier': 8,
#  'Ch1ll1Tiger': 1,
#  'MasTer': 26,
#  's4udi-j0k3r': 3,
#  'xerces': 84,
#  'hanicker': 24,
#  'foobar': 5,
#  'NanoyMaster': 17,
#  'a': 1,
#  'LordTittiS3000': 21,
#  'Langy': 229,
#  'nickhacks': 3,
#  'db': 48,
#  'Ne0h': 2,
#  'manachou': 2,
#  'keps': 1,
#  'DanielGodoy': 5,
#  'Lagripe-Dz': 1,
#  'Joshzilk': 1,
#  'h3rcul3s': 10,
#  'CypherChain': 1,
#  'dick': 34,
#  'NullByteKrew': 2,
#  '0x09': 1,
#  'hopihavet': 3,
#  'invisible_hacker': 28,
#  'RTK': 2,
#  'root_op': 7,
#  'strepo': 15,
#  'aBu.HaliL501': 1,
#  'abuhalil501': 2,
#  'KandemiR': 1,
#  'SnypterDhruv': 32,
#  'zm0d': 2,
#  'AnonymousWhiteHat': 1,
#  'b0x': 2,
#  '0x3a': 1,
#  'livinskull': 9,
#  'Hood3dRob1n': 21,
#  'Megid': 1,
#  'MaCaUt': 1,
#  'D4rkWeaver': 1,
#  'MC.Iglo': 3,
#  'FikriFadzil': 14,
#  'PAul': 1,
#  'Nyogtha': 1,
#  'Busi': 94,
#  'vir0e5': 10,
#  'nuclear': 1,
#  'c0mrad3': 1,
#  's4squatch': 2,
#  'orange': 14,
#  'CaTz': 9,
#  'BARCOD3': 3,
#  'sim0n': 1,
#  '[]0iZy5': 6,
#  'WaZo': 19,
#  'ATH-CREW': 3,
#  'Angle': 2,
#  'SPYROKiD': 15,
#  'Toad': 1,
#  'VMw4r3': 4,
#  'Snoopy': 2,
#  'Loko': 1,
#  'kabelbrand': 3,
#  'trueliarx': 30,
#  'kInGoFcHaOs': 249,
#  'Jinny': 1,
#  'JKS': 2,
#  'r3d7r0z@n': 2,
#  'BubbaDeluxe': 1,
#  'Diego': 1,
#  'ArashAllebrahim': 3,
#  'Pulk.it': 1,
#  'DutchFlower': 1,
#  'MaXoNe': 1,
#  'lljkrieg': 160,
#  'rvk': 1,
#  'xDarkston3x': 2,
#  'riSky': 1,
#  'pathetiq': 9,
#  'lol': 1,
#  '0bj3ctiv3@gmail.com': 1,
#  'Holyzone': 1,
#  'DigitalKryptonite': 9,
#  'WTC.LeGeND': 2,
#  'rVk_': 1,
#  '1337': 1,
#  '-Chosen-': 22,
#  'riccardo': 1,
#  'komiyan_': 1,
#  'Sora': 17,
#  'Genosite': 28,
#  'double_check': 58,
#  'KHS': 2,
#  'AAD': 1,
#  'incid3nt': 1,
#  'NeX': 27,
#  'DellNull': 25,
#  'spo0feR': 8,
#  'andythesniper': 1,
#  'Feg': 1,
#  'thejanky': 24,
#  'God_Of_Pain': 6,
#  'VittGam': 1,
#  'OmegaApex': 1,
#  'biosterminator': 1,
#  'Perow': 19,
#  'CruiseBG': 4,
#  'Abluka': 21,
#  'Cyworm.Com': 4,
#  'DerickTham': 210,
#  'AltF4': 3,
#  'TheRat': 115,
#  'Vezir.04': 1,
#  'Renoized': 176,
#  'Dglife': 1,
#  'Alexfoo': 5,
#  'APS': 51,
#  'IoloMorganwg': 5,
#  'syltrox': 9,
#  'Mr.Jurist': 1,
#  'Shogun': 1,
#  'banke-haromkhor': 1,
#  'shagrut': 1,
#  'beyrut-KaI3uS': 16,
#  'MartinHealion': 1,
#  'Moonzorg': 14,
#  'P.Daneshmand': 16,
#  'sKoRe2o4': 9,
#  '__Genius__': 14,
#  'Ufuq51': 2,
#  'cbr': 64,
#  'DavidShaw': 2,
#  'KhashayarFereidani': 1,
#  'r00tsvr': 1,
#  'Mosad': 1,
#  'Mutant': 111,
#  'UsluBey': 8,
#  'fred777': 8,
#  'alexalghisi': 31,
#  'LordTittiS': 13,
#  'Darkspoon12': 7,
#  'Noam': 1,
#  'Ahlspiess': 18,
#  'Pin0yeXpl0itTeam': 6,
#  'Lorin_Voutat': 1,
#  'XploitD': 1,
#  'Mr.tro0oqy': 1,
#  'THE-SH0CK-B0Y': 235,
#  'st0rmy-': 3,
#  'www.intelcomms.net': 45,
#  'GTADarkDude': 101,
#  'kernel_panic': 12,
#  'system_meltdown': 34,
#  'k3vinmitnick': 32,
#  'Lt.Jethawk': 1,
#  'Camilo-TcK': 199,
#  'HannoBoeck': 184,
#  'MicHeLoNy': 6,
#  'Daniel15': 5,
#  'Phreakaz0id': 5,
#  'h3xStream': 24,
#  'vac': 3,
#  'AzatHarutyunyan': 408,
#  'Mr.JacK': 7,
#  'JK3MP': 1,
#  'm4luck0': 2,
#  'OshadhaGunawardena': 1,
#  'dev0': 1,
#  'EsSandRe': 3,
#  'Squid': 2,
#  'blackboy1337': 18,
#  'VirusRoot': 1,
#  'c0wb0yc0d3r': 1,
#  'bursali': 6,
#  'xsrv': 3,
#  'Miusi': 32,
#  'surbo': 3,
#  'p4r4d0x': 1,
#  'EndCode': 2,
#  'H31nz': 1,
#  'TheLeader': 6,
#  'lwm1338': 1,
#  'psych0pat': 1,
#  'Xacker': 5,
#  'SolarFlare': 8,
#  '10Line': 4,
#  'dohedo': 1,
#  'roach189': 15,
#  'Mr.uNkN0wN': 1,
#  'whiteonce': 1,
#  'H4U': 1,
#  'SaMTHG': 488,
#  'EdgardChammas[454447415244]': 5,
#  'it3r': 2,
#  'EL_MuHaMMeD': 1,
#  'SandroGauci': 1,
#  'CyberDirector.Org': 6,
#  'DeathCharge9': 8,
#  'md.r00t': 20,
#  'moubik': 3,
#  'SaifAli': 3,
#  'A--': 1,
#  'bayunen': 1,
#  'kanur': 65,
#  '3KB3R': 21,
#  'Cruisebg': 1,
#  'bill': 118,
#  'Digivibe': 1,
#  'Invectus': 9,
#  'YB': 1,
#  'bcb5d2a46663f935e42815d73bdffc8f': 2,
#  'CWhokkabaz': 1,
#  'c4p_sl0ck': 25,
#  'Lostmon': 5,
#  'UzmiX': 18,
#  'FayHatti': 22,
#  'PetesBloodyHand': 4,
#  'SandeepKamble': 7,
#  'Spl3en': 1,
#  'TomU': 1,
#  '0kn0ck': 2,
#  'jmit': 3,
#  'L0K_o': 1,
#  'Greatest': 2,
#  'AndrewMacFie': 17,
#  'Pouya_server': 30,
#  'Gamoscu': 38,
#  'Brenn0': 21,
#  'Zeon369[French]': 1,
#  'NilsJuenemann': 1,
#  'Dazslayer': 1,
#  'xssnoob': 1,
#  'Ninja1337': 2,
#  'siL3ntpuPp3t': 1,
#  'AngleA.K.Amalwarrior': 1,
#  'bobbyLikesCheese': 1,
#  'BlackhatDBL': 3,
#  'Maximum': 1,
#  'airizon': 1,
#  'Alesteir': 1,
#  'alesteir': 1,
#  'Mtutnid': 6,
#  'r9s': 1,
#  'durlydurly': 1,
#  'dn5': 1,
#  'jami': 1,
#  '..': 1,
#  'Anon': 1,
#  'cueballr': 243,
#  'Skunkfoot': 88,
#  'r0xSoFT': 1,
#  '444Team': 66,
#  'TeaMp0isoN': 2,
#  'Pyske': 1,
#  'Taberani': 4,
#  'yehg': 1,
#  'modakabam': 27,
#  'f': 3,
#  'jjbutler88': 35,
#  'KeResS': 1,
#  'wildc4rd': 2,
#  'Darkc0ke': 14,
#  'hacku': 1,
#  'CEYHUN': 1,
#  'MHG': 5,
#  'cyber': 449,
#  'wolfmankurd': 4,
#  'Genesis': 1,
#  'SpankMP3': 1,
#  'Xbox2002': 9,
#  'Rogunix': 9,
#  '8rux0': 1,
#  'Manihack64': 1,
#  'vengadanathan': 1,
#  'TinKode': 10,
#  'TomKoniuta': 1,
#  'chipik': 1,
#  'fakhrul_sc2': 1,
#  '3st3': 4,
#  'keymaster': 1,
#  'Error403-forbidden': 3,
#  's-dz': 2,
#  'satyampujari': 1,
#  'Personoid': 1,
#  'iTZBANANO': 1,
#  'grupovul': 4,
#  '[SSTeam]theSnailSnapper': 4,
#  'AshiyaneDigitalSecurityTeam': 4,
#  'TruePromiseTeam': 2,
#  'h31nz': 1,
#  '5ubzer0': 1,
#  'ederwander': 2,
#  'zprian': 73,
#  's3cur1Ty-Dz': 1,
#  'arakawatomonori': 1,
#  'Cyberchrist': 3,
#  'bonaff': 1,
#  'SpecTrum_Bill': 2,
#  'Bl4ck3rk1ll': 1,
#  'gumb00t': 1,
#  'malwarrior': 1,
#  'Dunkel': 1,
#  'InSecurity.Ro': 2,
#  'rolancross': 2,
#  'musashi42': 2,
#  'Vorpal': 10,
#  'DDroid3': 1,
#  'Zer01': 1,
#  'AkashMahajan': 3,
#  'nicholson': 35,
#  'xyzjace': 1,
#  'SimonRolland': 1,
#  'allan': 1,
#  'Pragmatk': 57,
#  'bruxa': 9,
#  'DeepImpact': 13,
#  'harry-AT': 2,
#  'nv_quad': 9,
#  'Denven': 18,
#  'Mr.SpIdEy': 1,
#  'ekse': 2,
#  '23': 1,
#  'miss4pple': 1,
#  'THE_MILLER': 182,
#  'Poltergeisth4cker': 6,
#  'PMM': 1,
#  'Side3ffects': 3,
#  'sandeepkamble': 1,
#  'Encrypt3d.Mind': 4,
#  'eins11': 1,
#  'S4udi-S3curity-T3rror': 1,
#  'noreply': 3,
#  'MrSecret': 5,
#  'Free-Chain': 2,
#  'Pouya_Server': 14,
#  'euronymous': 4,
#  'Alaim-iZaaf': 10,
#  'By.DeJaVu': 2,
#  'Caborz': 2,
#  'meloulisi': 120,
#  'Alaim-izaaf': 10,
#  'murdercode': 18,
#  'Viana': 2,
#  'M4tRix': 3,
#  'Aions': 2,
#  'ingo86': 4,
#  'SomeGuy': 1,
#  'Cyber-holigan': 1,
#  'gamr': 9,
#  'fLP': 1,
#  'unwiredbrain': 4,
#  'Equilibrium': 1,
#  'mrkonar': 8,
#  'LionTurk': 2,
#  'Wireghoul': 5,
#  'Deuvede': 1,
#  'Norehem': 236,
#  'vlan7': 15,
#  'x41': 4,
#  'SripathiKrishnan': 3,
#  'MiladKhalafi': 1,
#  'xcr4ckx': 10,
#  'Honisan': 25,
#  'flayer': 1,
#  'SkyOut': 45,
#  '1nj3cth4x': 1,
#  'InjEctOr': 1,
#  'FullFreeez': 36,
#  'Tr0jAn': 45,
#  'Soroush.SecProject.Com': 4,
#  'EmrullahAkdemir': 1,
#  'Frost_Maturidi': 3,
#  'i1337': 11,
#  'DrkSniX': 5,
#  'evilops': 2,
#  'deVbite': 1,
#  'm0k4n1n4': 1,
#  'Airroxssed': 3,
#  'Yasion': 2,
#  'Syst3mCr4sh': 8,
#  'MrSlinky': 10,
#  'Dave': 8,
#  'zombielove': 3,
#  'Sr.': 17,
#  '0xyGen': 3,
#  'VEHUL': 9,
#  'n0p34ce': 1,
#  'MoralExploit': 3,
#  'sharpskater80': 12,
#  's0rento': 1,
#  'p4n1ck': 1,
#  'loxaXcracker': 53,
#  'eggDrop': 1,
#  'NetMafia': 1,
#  'Cybertrouble': 1,
#  'Milisx': 46,
#  'BuzuLL': 1,
#  'D3xeR': 3,
#  'ap101': 16,
#  'mrnarko': 1,
#  'frosT_maturidi': 8,
#  'GeNkStAr': 64,
#  'SatishKini': 1,
#  'CanDarK': 1,
#  'ELiMINATOR': 1,
#  'GabrielLima': 1,
#  'bigcody': 2,
#  'x0x': 4,
#  'nevillon_devilteam_quad': 8,
#  'The_0nur': 2,
#  'CrueLChiLd': 8,
#  'BhaveshKarodiwal': 2,
#  'n-bl4x': 3,
#  'neq': 2,
#  'j0rd4n14n.r1z': 3,
#  'PanterA': 9,
#  'sEtH-X-C3LL': 30,
#  'Rex_Mundi': 2,
#  'FQS685F4QD2FQS85AEFQSD': 1,
#  'bigc0dy': 2,
#  '599emeTeam': 8,
#  'speldworng': 5,
#  'uLkuCu': 2,
#  'TEMP': 6,
#  'ShockShadow': 4,
#  'kemadruma': 1,
#  'CWSpinoza': 2,
#  'HackedByAlpagut': 1,
#  'LeBaNeSe-XsSeR': 13,
#  'Rj-DevarA': 3,
#  'EGEMEN': 1,
#  'Genocide': 131,
#  'Stacker': 87,
#  'kesto': 2,
#  'Tipidy': 12,
#  'WOTAN_2300': 1,
#  'Ribel': 25,
#  'Futility': 53,
#  'RockeyKiller': 1,
#  'Kenneth_nap': 2,
#  'HeRo': 12,
#  'Blast': 17,
#  '1kt0m1': 1,
#  'postmaster': 3,
#  'stranac': 3,
#  'PierreCholhot': 1,
#  'Arvindkumar': 1,
#  'f_0': 3,
#  'devek': 1,
#  'XSSTORM': 4,
#  'BelgianSecurity': 1,
#  'cAs': 16,
#  'seo': 1,
#  'Hikapa': 3,
#  'FlashcRew': 1,
#  'rout3rx': 1,
#  'Vachequirit': 1,
#  'watermy': 2,
#  'pedlagdur': 1,
#  'Devek': 50,
#  'Inx_ro0takaMr.xxxx': 1,
#  'H0tTurk': 8,
#  'Amadeus': 4,
#  'G4MM4': 1,
#  'yehgdotnet': 1,
#  'Netdivers[P4p3R]': 1,
#  'Angelo': 1,
#  'Tom-PMS': 1,
#  'q0dr1x': 3,
#  'arSh': 1,
#  'HOLLYWOULD': 1,
#  'BlackOut': 3,
#  'StevenAbbagnaro': 13,
#  'Kakia': 3,
#  'BobSmith07': 1,
#  'zrok': 6,
#  'Zack': 1,
#  'DiegoSiqueira': 1,
#  'MURATHOCA': 7,
#  '-': 1,
#  'Euforia33': 9,
#  'r00t-_-h@cK3r': 3,
#  'robusta_': 8,
#  'ArascyberArmy': 1,
#  'blakboy1337': 1,
#  'nullby3t': 1,
#  'maligree': 5,
#  'nuLLf0x': 1,
#  'S@xx0R': 6,
#  'OleMoudi': 10,
#  'KishurPrabhakaran': 2,
#  'FZERO': 3,
#  'Cir0': 2,
#  'chiders': 8,
#  'C0nw0nk': 4,
#  'AjaySinghNegi': 2,
#  'GJvManen': 1,
#  'De[x]TeR': 3,
#  'eXeSoul': 2,
#  'TurkisH-RuleZ': 1,
#  'jeflui': 6,
#  'infosec-labs.com': 1,
#  'alexfoo': 4,
#  'MassimoLombardo': 2,
#  'elkrisu': 1,
#  'zurt': 1,
#  'FuckYeah': 1,
#  '189': 1,
#  'Alest0rm': 2,
#  'loGin.Dz': 2,
#  'byloGin.Dz': 2,
#  'Bastich': 5,
#  'nopic01': 35,
#  'unnex': 2,
#  'f0undIt': 1,
#  'Zesty': 1,
#  'd3vb1t3': 1,
#  'JosephFoulds': 4,
#  'Techie': 1,
#  'Amme': 1,
#  'OrucReis': 1,
#  'FuckDPD': 1,
#  'brahodoh': 1,
#  'Marian': 2,
#  'RaideNHackeR': 3,
#  'm4d': 1,
#  'qweqwe890': 1,
#  'todesblubber': 1,
#  'd3wls3': 1,
#  'dr0pper': 2,
#  'Kolor': 1,
#  'CiCoSz': 156,
#  'BlackApple': 1,
#  'AnthonyLaifromVXRL': 4,
#  'AlanHofromVXRL': 1,
#  'FLY_': 1,
#  'Mili': 1,
#  'TheLaughingMan': 2,
#  'GeorgeBobOrwell': 1,
#  'MatthewBoevink': 1,
#  'ademix': 6,
#  'FixTR': 1,
#  'HNicolai': 4,
#  'acemutha': 10,
#  'Yamakashi': 3,
#  '[]c0dy': 2,
#  'b3nsz4': 4,
#  'uMTu': 1,
#  'DOSed': 3,
#  'TrSoldier': 1,
#  'new_hack8912': 1,
#  'Overhead': 9,
#  'BlackMonkey': 1,
#  'TeRoRisTe_Mc': 1,
#  'Zer0Thunder': 1,
#  'abhisheklyall': 2,
#  'Montazer313DigitalSecurityTeam': 1,
#  'dpnkr': 1,
#  'lionaneesh': 1,
#  'pulketo': 2,
#  'Stoik': 13,
#  'Krutoy': 3,
#  'Devi1x': 1,
#  'h3rcul3s1': 2,
#  'Audran': 2,
#  'l0bster': 17,
#  'DEADB17Ch': 3,
#  'Rapt0r': 3,
#  'hex': 1,
#  'austinator': 53,
#  'SilvyanO': 3,
#  'Int_13h': 2,
#  'TheMessy': 17,
#  'dR.sqL': 1,
#  'Ma3str0-Dz': 1,
#  'istehem': 2,
#  'zero': 1,
#  'HackedbyMontazer313DigitalSecurityTeam': 1,
#  'CocainTeaM': 8,
#  'AKIRA': 1,
#  '0xFF_org': 2,
#  'starofale': 4,
#  'MinhalMehdi': 1,
#  'TheDr1ver': 1,
#  'ByEge': 1,
#  'indrimuska': 1,
#  'Ma3sTr0-Dz': 7,
#  'Jonturk75': 1,
#  'g4ms3': 7,
#  'NoTty_rAJ': 1,
#  'UeCr3w': 3,
#  'MariusSchiffer': 1,
#  'fr0stbite': 2,
#  'Gh0stSniper': 1,
#  'Wh0p5': 1,
#  'ToPN1K': 3,
#  '3348399': 4,
#  'RubenvanVreeland': 1,
#  'MANOJKUMARSINGH': 1,
#  'Infam0us': 2,
#  'stupid': 1,
#  'orbulat': 2,
#  'TusharDhruvabalParab': 1,
#  'Nazghrell': 4,
#  'DarkAnonymous': 1,
#  'Prakhar': 2,
#  'TheMirkin': 2,
#  'stitchup': 4,
#  'DanBUK': 7,
#  'Bl4k3': 1,
#  'trv': 7,
#  'RomanceMint': 1,
#  'DaNg3R': 2,
#  'Electr0nLibre': 1,
#  'LUPUS': 4,
#  'hackebeil': 1,
#  'BrendanColes': 1,
#  'Pbh420': 1,
#  'bonsaiviking': 1,
#  'Kokoriko': 1,
#  'Wolf-Ma': 1,
#  'iam': 1,
#  'Cyber-Thief': 1,
#  'AlexAltea': 9,
#  'xb0y': 1,
#  'K4mi': 1,
#  'KnickLighter': 2,
#  'RFBlackfire': 1,
#  'D': 1,
#  'jasat': 1,
#  'FenniC': 1,
#  'bn3d': 1,
#  'anonymous': 6,
#  'Mudkip': 3,
#  'Kn0t': 1,
#  'K0242': 1,
#  'mdeaPoC': 2,
#  'Th3xin0x': 10,
#  '7uK4c': 1,
#  'CCC': 561,
#  'le1ito': 3,
#  'Samurai': 3,
#  'lnxg33k': 1,
#  'TugrulAlpdogan': 1,
#  'MadmanTM': 2,
#  'BrainStorm': 1,
#  'ajhiscocks': 1,
#  ...}
