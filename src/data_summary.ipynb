# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

DATA_DIR = '../data'
DATA_FILE = 'mirror.csv'

data_file = os.path.join(DATA_DIR, DATA_FILE)

# %%
data = pd.read_csv(data_file)
data.head()
# Out:
#   Datesubmitted Datepublished   Status           Author  \
# 0    18/08/2014    13/03/2015  UNFIXED   SquirrelBuddha
# 1    05/01/2014    13/03/2015    FIXED          puritys
# 2    15/11/2013    13/03/2015    FIXED     ArianaGrande
# 3    06/10/2014    13/03/2015  UNFIXED         MrCyph3r
# 4    09/08/2012    13/03/2015    FIXED  FabianCuchietti
#
#                                Domain Category  Pagerank  \
# 0  webcenters.netscape.compuserve.com      XSS     70880
# 1                   store.samsung.com      XSS       340
# 2                        auth.dhs.gov      XSS      4057
# 3                   www.titivillus.it      XSS  11882046
# 4                    www.brazzers.com      XSS      1755
#
#                                                  URL
# 0  http://webcenters.netscape.compuserve.com/weat...
# 1  http://store.samsung.com/uk/camera/smart-n2x">...
# 2  https://auth.dhs.gov/oam/hsinlogin/?authn_try_...
# 3  http://www.titivillus.it/periodico.php?id=15%3...
# 4  http://www.brazzers.com/series/view/episodes/%...

# %%
# pagerank distribution
data['Pagerank'].hist(bins=30)

# %%
from collections import Counter, OrderedDict
ct_result = dict(Counter(data['Author']))
ct_result
# Out:
# {nan: 1,
#  'hex': 1,
#  'DigitalBoysUnderground': 1,
#  'Thefucker': 29,
#  'mYSTICK': 1,
#  'Jimmy': 1,
#  'Keeper': 1,
#  'Wolfrat': 1,
#  'Gianluka_95': 3,
#  'K_I_N_G': 2,
#  'Warezk': 1,
#  'iD-uNkn0wn.eu': 11,
#  'croconile': 1,
#  'frite': 1,
#  'Soroush.Secproject.com': 1,
#  'SkyOut': 45,
#  'vac': 3,
#  'Agent-Z': 3,
#  'AnLuZ': 1,
#  'bigc0dy': 2,
#  'postal': 5,
#  'ALiEN': 1,
#  'by_casper41': 87,
#  'TheX-C3LL': 1,
#  'ResisTance': 30,
#  'SwartMumba': 1,
#  'keyrox': 1,
#  'Dv9': 2,
#  'SpecTrum_Bill': 2,
#  'v30sharp': 1,
#  'S_e_YM_e_N': 209,
#  'M-K-A': 3,
#  'viperfx': 2,
#  '.virex': 9,
#  'cobra90nj': 1,
#  'ippon': 1,
#  'NexusOveride': 1,
#  'hypn0sis': 1,
#  'Bengali': 1,
#  'BeyazKurt': 49,
#  'hacker-e-kiri': 1,
#  'MaxDietz': 1,
#  'kusomiso': 1,
#  'syst3m_f4ultghableinkelammerbazibeshe': 1,
#  'hanicker': 24,
#  'St@R-gaZ3r': 174,
#  'KTJM': 1,
#  'PKDooM2007': 2,
#  'lithium9': 14,
#  'banke-haromkhor': 1,
#  'Honisan': 25,
#  'turbocharged_06': 4,
#  'Manihack64': 1,
#  'Hack-labs': 5,
#  'nullby3t': 1,
#  'C1c4Tr1Z': 308,
#  'AbSoluTe_ZeRo': 3,
#  's1ckb0y': 1,
#  'hepyeq': 1,
#  'Mr.PaPaRoSSe': 2,
#  'Vektor': 2,
#  'klaus': 2,
#  'BoxHead': 1,
#  'NicholasLemonias': 1,
#  'Xerces': 1,
#  'AshiyaneDigitalSecurityTeam': 4,
#  'K1nk0': 2,
#  'BukiBv': 2,
#  'GianniAmato': 2,
#  'zm0d': 2,
#  'xsrv': 3,
#  'Sh0ck': 4,
#  'pouya_server': 9,
#  'Ginetto': 1,
#  'z0mb.ie': 1,
#  '3kb3ruqan': 41,
#  'dick': 34,
#  'Rj-DevarA': 3,
#  'MamedTek': 1,
#  'OmegaAp3x': 6,
#  'MURATHOCA': 7,
#  'Filbert': 10,
#  'R3DTURK': 4,
#  'ViperaT': 1,
#  'S3RD4R': 3,
#  'Anonymous[Fr]': 1,
#  'hitcher': 4,
#  'mdeaPoC': 2,
#  'PanterA': 9,
#  'By_Ogmass': 1,
#  'wh4ttheh3ck': 1,
#  'good.boy208': 1,
#  'pathetiq': 9,
#  'NetJackal': 2,
#  'kaerast': 14,
#  'Zeon369[French]': 1,
#  'shopchick-fil-a.com': 1,
#  'nullbyt3POC': 1,
#  'CCC': 561,
#  'h4v0c-': 1,
#  'Devi1x': 1,
#  'celciuz': 49,
#  'AskeriHarekat': 22,
#  'frost_maturidi': 9,
#  'XPEHOTAC': 8,
#  'Shotokan-TheHacker': 3,
#  'syspl0it': 4,
#  'd4rkcode': 1,
#  'zer0flag': 4,
#  'cherokeewarrrior': 1,
#  'dR.sqL': 1,
#  'SuNHouSe2': 7,
#  'Mutant': 111,
#  'SiLent-Death': 1,
#  'Panther-RooT': 10,
#  'RoAd_KiLlEr': 12,
#  'TurkProtest': 4,
#  'LightsOut': 2,
#  'HackedbyMontazer313DigitalSecurityTeam': 1,
#  'PanZerTurK': 7,
#  'JJFourOneOne': 1,
#  'A3on': 20,
#  'ultramegaman': 1,
#  'Aleks': 11,
#  'Ic3Drag0n': 18,
#  'acemutha': 10,
#  'z9': 6,
#  'Zer0day': 2,
#  'eX0dus': 31,
#  'Angelo': 1,
#  'Trii': 6,
#  'vagoybostero': 1,
#  'Chenator': 3,
#  'b': 1,
#  'Futility': 53,
#  's3cur1Ty-Dz': 1,
#  's1l3nt4rmy': 1,
#  'sashrigby': 2,
#  'TheWorldsHackeR': 1,
#  'oh': 1,
#  'Zool': 1,
#  'b0x': 2,
#  'FatalAttack': 1,
#  'alert_x3': 1,
#  'BlueMax': 149,
#  'Xylitol': 468,
#  'TheLittleOne': 1,
#  'yzarc': 13,
#  'p3lo': 47,
#  '0x6834636b': 4,
#  'Droid': 11,
#  'maLa': 1,
#  'TurKReiS': 2,
#  'soaj1664ashar': 1,
#  'bogey': 1,
#  'Pouya_Server': 14,
#  'Equilibrium': 1,
#  'STF': 1,
#  'CodyR.': 1,
#  'Felipower': 1,
#  'orange': 14,
#  'HardPorn': 1,
#  'Aitoc': 3,
#  'Pin0yeXpl0itTeam': 6,
#  'Shamil_Basayev': 2,
#  'EuropaFan': 2,
#  'Nexus': 1,
#  '04hrb': 1,
#  'MarioPEREZ': 1,
#  'benjaminflesch': 3,
#  'SaifuddinAmri': 1,
#  'LohitTummalapenta': 3,
#  'DeathCharge9': 8,
#  'blackboy1337': 18,
#  'al3x_0wn5': 1,
#  'gordon_Freeman': 1,
#  'Miusi': 32,
#  'm3hr4n': 28,
#  'dhony': 1,
#  'dar3co1l': 2,
#  'Phanter-RooT': 1,
#  'RedToor': 1,
#  'delirium': 1,
#  'Ag-Guvenlik': 1,
#  'Belthazored': 1,
#  'EhsanIce': 2,
#  'winkmaster': 1,
#  'LaurentD': 1,
#  'GeoxX': 1,
#  'Agd_Scorp': 42,
#  'loshiq': 7,
#  'sEtH': 1,
#  'KvK': 2,
#  'X4X4X4X4': 19,
#  'IMHOT3B': 1,
#  'U238': 2,
#  'OrionEinfold': 1,
#  'soldier': 2,
#  'ratzrattillo': 1,
#  'autoexectrojan': 1,
#  'S0m.ph': 25,
#  'Mystick': 824,
#  'sef': 1,
#  'chipsandcurry': 1,
#  'fil3st0rm': 1,
#  'NileshSubmissionforOpenRedirect': 1,
#  'Ac1d': 2,
#  'Dark_net': 4,
#  'kanur': 65,
#  'nv_quad': 9,
#  'FayHatti': 22,
#  'DigitalMind': 1,
#  'Mor-DunyA': 16,
#  'Vickram': 2,
#  'ademix': 6,
#  'loverboy': 1,
#  'Vagrant': 338,
#  'JohnSoutar': 3,
#  'AudisoftHackerTeam': 1,
#  'Vajra': 1,
#  'AR3SW0RMED': 170,
#  'keymaster': 1,
#  'Smokey': 2,
#  'By_Cyber': 20,
#  'r00tsvr': 1,
#  'n0p34ce': 1,
#  'frosT_Maturidi': 151,
#  'lolh4x': 3,
#  'CrimaL': 1,
#  'Anon': 1,
#  'Loser': 2,
#  '0xyGen': 3,
#  'd0cent': 1,
#  'MustLive': 5,
#  'Madhur': 1,
#  'JosS': 5,
#  'alkolkafayapar': 1,
#  'Saelyx': 1,
#  'Rollingdice': 1,
#  'Xonzai': 1,
#  'SilvyanO': 3,
#  'zoksi': 1,
#  'mghack': 26,
#  'Sha1': 1,
#  'EL_MuHaMMeD': 1,
#  'AlexAltea': 9,
#  'nanoymaster': 17,
#  'MiroslavLucinskij': 2,
#  'b0rizQ': 1,
#  'Security-TR': 1,
#  'b4dsect0r': 2,
#  'UnknownFromHell': 9,
#  'Ras': 5,
#  'ap101': 16,
#  'ehsan_hp200': 1,
#  'Virtual_SystEm': 88,
#  'str0nge': 1,
#  'AnTi-SysTeM': 1,
#  'n-bl4x': 3,
#  'hagbardceline': 2,
#  'Prakhar': 2,
#  'Mr.Jurist': 1,
#  'BugReport.ir': 4,
#  'OmegaApex': 1,
#  'rolancross': 2,
#  'Hacxer': 12,
#  'Mutiny': 1,
#  'Rhinos': 1,
#  'Busindre': 1,
#  'LuisGuilhermeBrunck': 9,
#  'LordTittiS': 13,
#  'pizzahut.es': 1,
#  'Hotpockets': 236,
#  'bursali': 6,
#  'AttackersUS': 1,
#  'AlexanderFuchs': 2,
#  'sandeepkamble': 1,
#  'ironzorg': 203,
#  'r9s': 1,
#  'bugReport.ir': 1,
#  'K4mi': 1,
#  'Gr1mr3p34': 1,
#  'A.D.T': 42,
#  'CoreDump': 1,
#  'Idahc': 4,
#  'ForzaMira': 1,
#  'Devek': 50,
#  'DosbartJones': 1,
#  'sypher': 1,
#  'ahmed': 1,
#  'Megid': 1,
#  'Techie': 1,
#  'aleks': 1,
#  'viperfx07': 9,
#  'Megabyte': 2,
#  'IrIsT.Ir': 97,
#  'burp': 1,
#  'asirr': 3,
#  'MasteR_': 1,
#  'DialogitecImeCiQ': 34,
#  'MUS4LLAT-JoCk3r': 8,
#  'WOTAN_2300': 1,
#  'Mityo': 1,
#  'pulketo': 2,
#  'Mekruh': 1,
#  'centrinel': 4,
#  '0xFF_org': 2,
#  'Baybora': 1,
#  'HappyCatSecurityCrew': 1,
#  'Napst3r': 1,
#  'Mili': 1,
#  'svantevit': 1,
#  'TrSoldier': 1,
#  'EjRaM-HaCkEr': 1,
#  'spyboy': 1,
#  '454447415244': 1,
#  'Cr4t3r': 15,
#  'solo': 16,
#  'C0BRA': 1,
#  'GavInc': 1,
#  '0z0n3': 1,
#  'MANOJKUMARSINGH': 1,
#  'EduardoAbril': 2,
#  'ZH4RK': 1,
#  'DDXhunter': 8,
#  'ScraGgs': 1,
#  'd3vb1t3': 1,
#  'insubordination': 1,
#  'black.spook': 1,
#  'nohone': 1,
#  'SolarFlare': 8,
#  'Alemin_Krali': 13,
#  'xb0y': 1,
#  'Codeine': 1,
#  'mandi': 1,
#  'r14nul': 3,
#  'pimpim': 52,
#  'roboteto': 3,
#  'CoNSPiRaToR': 3,
#  'SmokeyDelVecchio': 1,
#  'ThamWenHaur': 1,
#  'ATH-CREW': 3,
#  'TheLaughingMan': 2,
#  'cyber_thief': 23,
#  's4r4d0': 1,
#  'ArascyberArmy': 1,
#  'HackedNarcoticxs': 2,
#  'Therat': 4,
#  'Fzero': 16,
#  'SasiLevi': 1,
#  'J-Hacker': 1,
#  'zimy': 1,
#  'The_0nur': 2,
#  'TeaMpoisoN': 3,
#  'PsychoHash': 1,
#  'Reelix': 45,
#  'lionaneesh': 1,
#  'az7rb': 2,
#  'TheDr1ver': 1,
#  'MHG': 5,
#  'JosephFoulds': 4,
#  'Securitylab.ir': 36,
#  'mrnarko': 1,
#  'D3xeR': 3,
#  'megattack': 3,
#  'cloud': 1,
#  'BuTTerFr33': 1,
#  'HediMlika': 1,
#  'f_0': 3,
#  'ArashAllebrahim': 3,
#  'Troy': 1,
#  'iNs': 3,
#  'Montazer313DigitalSecurityTeam': 1,
#  'zurt': 1,
#  'bileltunisia': 5,
#  'xadet3': 24,
#  'kInGoFcHaOS': 1,
#  'cAtNiP': 1,
#  'Bolle': 5,
#  'n4ru70h4x0r': 1,
#  'manga': 2,
#  'Domino': 1,
#  'Hack2er': 1,
#  'D4rkWeaver': 1,
#  'iTZBANANO': 1,
#  'Nyogtha': 1,
#  'ChristianSciberras': 3,
#  'Thunderstorm': 5,
#  'Alexfoo': 5,
#  'Uber0n': 2064,
#  'anon': 2,
#  'd4rk-h4ck.com': 20,
#  'CirculoInformatico': 1,
#  'noptical': 1,
#  'km0t': 4,
#  'DEADB17Ch': 3,
#  'CnCxzSec': 1,
#  'Killer-TR': 61,
#  'mr_noob': 2,
#  'MH-IA': 1,
#  'durlydurly': 1,
#  'ZyrgEr': 1,
#  'DOSed': 3,
#  'j0rd4n14n.r1z': 3,
#  'Sameer': 1,
#  'ByEge': 1,
#  'Turklerklani': 2,
#  'KHS': 2,
#  'DeArEviL': 3,
#  'TheRat': 115,
#  'Squid': 2,
#  'By0ktay-DeeperS': 1,
#  'IvanSanchez': 1,
#  'AlpHaNiX': 2,
#  'XSSed': 1,
#  'FakeHuman': 15,
#  'Oleg07': 1,
#  'jmit': 3,
#  'PMM': 1,
#  'dom': 1,
#  'Hood3dRob1n': 21,
#  'Rex_Mundi': 2,
#  'worldwideweb': 1,
#  'Ayr4': 16,
#  'www.stat.harvard.edu': 1,
#  'ult_raslan58': 2,
#  'alexfoo': 4,
#  '14house': 42,
#  'CruelChild': 2,
#  'God_Of_Pain': 6,
#  'ScamZ': 1,
#  'InSecurity.Ro': 2,
#  'Wh0p5': 1,
#  'SandeepKamble': 7,
#  'r3t': 1,
#  'Bl4k3': 1,
#  'iNsuNkn0wn.eu': 1,
#  'bate': 50,
#  'Dimitrix': 4,
#  'MaCaUt': 1,
#  'JK3MP': 1,
#  'SaMTHg': 3,
#  'synopsi': 1,
#  'DavidShaw': 2,
#  'JuMp-Er': 1,
#  '0kn0ck': 2,
#  'rvk': 1,
#  'XXX': 1,
#  'Atmon3r': 480,
#  'HelloOfficial': 1,
#  'flexxpoint': 64,
#  'grupovul': 4,
#  'tr0n': 1,
#  'kerzua': 5,
#  'MaXoNe': 1,
#  'Kokoriko': 1,
#  'Zamani': 1,
#  'rex_mundi': 9,
#  'matrix': 1,
#  'spY.d0x': 4,
#  'Nilix': 1,
#  'Kingcaio': 1,
#  'siems': 1,
#  'unskilled': 1,
#  'Sph1nX': 1,
#  'Alexalghisi': 2,
#  'bok': 1,
#  'x3j46': 40,
#  'zombielove': 3,
#  's3rver.exe': 2,
#  'h31nz': 1,
#  'account.login.aol.com': 1,
#  'FuRKy': 1,
#  'WhiteRabbit101': 1,
#  'sle1306': 4,
#  '1zrrah': 3,
#  'TeaMp0isoN': 2,
#  'g4br1': 7,
#  'd3wls3': 1,
#  'BizaRRo': 18,
#  'riyazwalikar': 1,
#  'shad': 1,
#  'WolfML': 1,
#  'Lulwution': 1,
#  'Juf': 1,
#  'N3': 4,
#  'Smegol': 1,
#  'SECpplSUCKS': 1,
#  'HaCkSpY': 2,
#  'Xss': 2,
#  '[UTB]Diablo': 1,
#  'AceldamA': 1,
#  'Xbox2002': 9,
#  'Janizary': 10,
#  'Raven': 1,
#  'KiLiCaRsLaN': 1,
#  'k.': 1,
#  '0xAli': 2,
#  'KRaLBaY': 1,
#  'BlackFox': 6,
#  'Bl3ck0uT': 1,
#  'gotroot': 1,
#  'ScripterHack': 1,
#  'joker_s': 39,
#  'Potential_Quilty': 2,
#  'Soroush.SecProject.com': 1,
#  'Sympleboy22': 1,
#  'MartinH': 3,
#  'Neo-D': 2,
#  'Busi': 94,
#  'CSO-BR': 1,
#  'aaaaaaaaa': 1,
#  'tweetycoaster': 25,
#  'Yachi': 22,
#  'LeKhuongDuy': 1,
#  'RSnake': 2,
#  'Tr8': 3,
#  'DanBUK': 7,
#  'ArkanSuleymanovic': 4,
#  'keka': 1,
#  'AnonymousWhiteHat': 1,
#  'PanzErTurK': 12,
#  'Cyber-holigan': 1,
#  'Joyb0y': 3,
#  'SpY-MaD': 1,
#  'SpyGrup.Org': 1,
#  'Viaccess': 1,
#  'P.A.': 1,
#  'ftp21': 19,
#  'Marian': 2,
#  'uLKuCu': 1,
#  'johnkerry': 1,
#  'p4inl0v3r': 1,
#  'Ghaemiyeh': 1,
#  'XSS': 2,
#  'wutsec': 18,
#  'slic3menic3': 6,
#  'heroma': 1,
#  'demonoid': 1,
#  'Netdivers[P4p3R]': 1,
#  'milka': 3,
#  'Kuchi': 1,
#  'matt0': 5,
#  'lejoner': 21,
#  'EBRSecurity': 1,
#  'DellNull': 25,
#  'Flux': 1,
#  'LUPUS': 4,
#  'trueliarx': 30,
#  'KelsCat': 1,
#  's3m00t': 11,
#  'PAtO': 3,
#  'PD': 263,
#  'The-k0Lpa': 1,
#  'pr0n': 1,
#  'B': 2,
#  'Ravac': 84,
#  'BugREPORT.ir': 1,
#  'ZhcPoint': 2,
#  'nicobar': 1,
#  'MinhalMehdi': 1,
#  'Beenu': 1,
#  'garwga': 1,
#  'X3R0': 19,
#  'HaNniBaLKsA': 2,
#  'CambazTr': 1,
#  'c4p_sl0ck': 25,
#  'Dazslayer': 1,
#  'TheLegend': 8,
#  'l3d': 37,
#  'esteban': 1,
#  'ib00sti': 14,
#  'zarflax': 1,
#  'Moshbat': 1,
#  'Ryuzaki': 3,
#  'trisn': 6,
#  'sleazypete': 1,
#  'brendandonhue': 1,
#  'Overdose': 1,
#  'root1981': 1,
#  'aaa': 1,
#  'X-Turk': 13,
#  'Sc@ry': 35,
#  'ZATAZ': 1,
#  'ELiMINATOR': 1,
#  'meloulisi': 120,
#  'Al3x0wn5': 1,
#  'yehg.co.nr': 3,
#  'MK': 1,
#  'Rivijx7k0s': 6,
#  'fred777': 8,
#  'Mtutnid': 6,
#  'n93n93k': 2,
#  'ViniciusViana': 14,
#  'BARCOD3': 3,
#  'CyberTrouble': 3,
#  'NightDragon': 1,
#  'Soroush.SecProject.Com': 4,
#  'system_meltdown': 34,
#  'x0x': 4,
#  'Xermes': 1,
#  'mityo': 4,
#  'alexalghisi': 31,
#  'cYberPuNkz-SeCbRAkeRz-': 1,
#  'MatiasVicente': 29,
#  '3spi0n': 6,
#  'Muplah': 1,
#  'Black-Hacker': 2,
#  'AkashMahajan': 3,
#  'dev0': 1,
#  'KhashayarFereidani': 1,
#  'firemaze': 1,
#  'peekay': 2,
#  'LupuS': 1,
#  'CyberDon': 2,
#  'internet': 26,
#  'CyberTerminator': 1,
#  'samir-dz': 1,
#  'Trick0r': 1,
#  'f0undIt': 1,
#  'WhatALegend': 24,
#  'Sudani-Hacker': 5,
#  'RealsiZ': 2,
#  'DigitALL': 2,
#  'PredragCujanovic': 4,
#  'InSiDe': 22,
#  'wzzing': 1,
#  'Norehem': 236,
#  'UR0B0R0X': 4,
#  'ISYAN': 1,
#  'By.DejaVu': 1,
#  'AzatHarutunyan': 1,
#  'NullByteKrew': 2,
#  'AGD_SCORP': 3,
#  'Duke': 1,
#  'a': 1,
#  'K3rN3L': 1,
#  'HackTalk.net': 1,
#  'BugBuster': 53,
#  'CoLL1eR': 29,
#  'Maximum': 1,
#  'Zmx': 3,
#  'st@rext': 278,
#  'PaPPy': 882,
#  'kevinhorvath': 1,
#  'omoituki_ex': 10,
#  'h8k@hotmail.it': 1,
#  'xDarkSton3x': 3,
#  'H@ZRET': 2,
#  'SecreT': 4,
#  'eXeSoul': 2,
#  'md.r00t': 20,
#  'Soad': 1,
#  '44414E.15': 2,
#  'NurBoNegro': 15,
#  'VijayendraNigam': 54,
#  'speldworng': 5,
#  'Skyr3x': 37,
#  'NishantDasPatnaik': 2,
#  'Redworm': 2,
#  'Matrix[S.B]': 1,
#  '13': 1,
#  'Lalapanzi': 23,
#  'riccardo': 1,
#  'Feg': 1,
#  'TugrulAlpdogan': 1,
#  'slake': 6,
#  'SaifAli': 3,
#  'double_check': 58,
#  'Grannix': 1,
#  'TinKod': 1,
#  'k3vinmitnick': 32,
#  'S@xx0R': 6,
#  'hayaletkral': 69,
#  'AnthonyLaifromVXRL': 4,
#  'orbulat': 2,
#  'SASS': 1,
#  'Yacin': 1,
#  '-[SiLeNtp0is0n]-': 2,
#  'RPLK': 1,
#  'd@ydream': 1,
#  'alanh0': 1,
#  'lljkrieg': 160,
#  'SyPoTiX': 2,
#  'WIBF': 1,
#  'DerickTham': 210,
#  'AngleA.K.Amalwarrior': 1,
#  'LastLost': 1,
#  'WongChiehYie': 53,
#  'foobar': 5,
#  'cueballr': 243,
#  'Bastich': 5,
#  'Samurai': 3,
#  'xerces': 84,
#  'Anonymous': 62,
#  'BlackCode': 12,
#  'Andryxxx': 1,
#  'nemesis.te-home.net': 1,
#  '142TeeTH': 34,
#  'AVENUE-': 1,
#  'cr0xip': 1,
#  'DyDa': 1,
#  'ilike.ccie': 1,
#  'Tec-n0x': 40,
#  'DjH': 2,
#  'khameli': 1,
#  'codenaur': 3,
#  'dotty': 1,
#  'Jesus': 1,
#  'Arkadas': 1,
#  'UzmanHacker.Org': 1,
#  'iNs-uNkn0wn.eu': 5,
#  'SLiPHeaD': 1,
#  'usrlocalbin': 1,
#  'Flashback': 1,
#  'iam': 1,
#  'LemonWarez': 1,
#  'M-Ray': 20,
#  'Protect0re': 1,
#  'Tr3v0r': 1,
#  'Tr0n': 1,
#  'Amme': 1,
#  'gumb00t': 1,
#  'Fucker': 1,
#  '0wn3d_5ys': 1,
#  'EdgardChammas[454447415244]': 5,
#  'P': 1,
#  'Tribreaker': 2,
#  'PaT': 3,
#  'arSh': 1,
#  'tek0t': 1,
#  'sasquatch': 4,
#  '1kt0m1': 1,
#  'johnjuan728': 1,
#  'pcastagnaro': 4,
#  'SouhailHammou': 1,
#  'bonaff': 1,
#  'MoralExploit': 3,
#  's1nx': 1,
#  'DarkCOD3R': 4,
#  'rockyou': 1,
#  'p4n1ck': 1,
#  'M4ke': 1,
#  'OleMoudi': 10,
#  'MadAgent': 5,
#  'geisha': 1,
#  'seth': 1,
#  'cyber-hell.org': 1,
#  'virtualknight': 1,
#  'pH8': 1,
#  'Inx_ro0takaMr.xxxx': 1,
#  'Comando': 22,
#  'ThePr0ph3t': 1,
#  'doughboy': 2,
#  'Elias': 1,
#  '[_ATTRIBplusH_]': 1,
#  'V1P3R': 4,
#  'Taberani': 4,
#  'BiG-H': 1,
#  'q0dr1x': 3,
#  'baltazar': 6,
#  'Ma3sTr0-Dz': 7,
#  'l0bster': 17,
#  'LaFreepouille': 1,
#  'stitchup': 4,
#  'Msk': 5,
#  'adamb': 1,
#  'Stacker': 87,
#  'BlackLorD': 1,
#  'thelittleone': 1,
#  'MikeBailey': 6,
#  'C37HUN': 2,
#  'Vishrut': 1,
#  'andythesniper': 1,
#  'Metanet': 2,
#  'ratakurex': 8,
#  'SeYYaR_MaFYa': 1,
#  '0x44616E69656C3135': 1,
#  'YasinOzel': 1,
#  'nexen': 2,
#  'Rogunix': 9,
#  'ZuLL': 30,
#  'Agent-47': 1,
#  '4D1': 1,
#  'mebx': 6,
#  'Bam': 8,
#  'micshirau': 2,
#  'KnickLighter': 2,
#  'ZxX': 3,
#  'NetFuzzer': 24,
#  'justsomedude': 1,
#  'micr0': 1,
#  '444Team': 66,
#  'TrainReq': 3,
#  'frankdelion': 5,
#  'sasi2103': 4,
#  'sam': 1,
#  'Khe-Chi': 1,
#  'LarsStrojny': 47,
#  'Zack': 1,
#  'UnixCracker': 5,
#  'Int_13h': 2,
#  'SnL_ayaz_': 3,
#  'fabatka': 15,
#  'c0mrad3': 1,
#  'PirateAL': 1,
#  'gankzor': 1,
#  'mike001': 1,
#  'cyber': 449,
#  'Kami': 2,
#  'Josh21227': 1,
#  'mck': 1,
#  'VirusRoot': 1,
#  'KinSize': 1,
#  'Space-cowboY': 3,
#  'AidanMcGinley': 1,
#  'Marquinho': 1,
#  '03storic': 28,
#  'RomanceMint': 1,
#  'sameersaran': 1,
#  'ruzgar_18': 7,
#  'b4xX': 1,
#  'F0RTYS3V3N': 6,
#  'BBc04': 19,
#  'Toradiun': 1,
#  'DavidWharton': 1,
#  'korg': 2,
#  'franx47': 1,
#  'Denven': 18,
#  'PhilipClarke': 1,
#  'pH4nToM': 18,
#  'killer_null': 1,
#  'Sid3effects': 1,
#  '1NF1N1TY': 1,
#  'TeRoRisTe_Mc': 1,
#  'redc0de': 1,
#  'necromoine': 3,
#  'ExploitingNet': 1,
#  'DanielGodoy': 5,
#  'new_hack8912': 1,
#  'anon2k': 1,
#  'XyLeM': 1,
#  'Tr0jAn': 45,
#  'fx0': 1,
#  'XploitD': 1,
#  'Italiano': 1,
#  'nojuack': 1,
#  'holisticinfosec.org': 1,
#  'FiReOfDaRkNesS': 1,
#  'HuGe': 1,
#  'watt': 77,
#  'BlooX': 2,
#  'doeza': 7,
#  'xCero': 1,
#  'musashi42': 2,
#  'Alaim-iZaaf': 10,
#  'CWSpinoza': 2,
#  'HFUnreal': 2,
#  'nou': 1,
#  '4rm4g3dd0n': 1,
#  'JonathanStockton': 1,
#  'telnes': 1,
#  'Cyberchrist': 3,
#  'vulnerableagain': 3,
#  'SpankMP3': 1,
#  'AMON[RA]': 1,
#  'Xorphem': 1,
#  'By.DeJaVu': 2,
#  'siL3ntpuPp3t': 1,
#  'SnS': 12,
#  'Ashiyane': 1,
#  'nameless': 3,
#  'Andrew': 1,
#  'brahodoh': 1,
#  'gudgip': 26,
#  'LanceUppercut': 1,
#  'crashbird': 2,
#  'HACKEDBY_JAPAN': 1,
#  '4815162342': 5,
#  'r007k17': 5,
#  'none': 2,
#  'Timse': 11,
#  '3348399': 4,
#  'Shad0wman': 1,
#  'DeepakKivande': 1,
#  'Vezir.04': 1,
#  'Codenaur': 14,
#  'H4RDW1R3D': 6,
#  'PaoloDiFebbo': 2,
#  'syltrox': 9,
#  'Erox91': 2,
#  'Vh.alaki': 1,
#  'w3pt': 2,
#  '[]c0dy': 2,
#  's4squatch': 2,
#  'modakabam': 27,
#  'sk3tch': 1,
#  'F0lk3n': 2,
#  'GTADarkDude': 101,
#  'KaBus': 2,
#  'MatthewBoevink': 1,
#  'SquirmyBeast': 1,
#  'DanielHugh': 1,
#  'lox': 1,
#  'BrendanColes': 1,
#  'CaRRiSMaTuRK': 8,
#  'MicheleSpagnuolo': 1,
#  'Zeryus': 163,
#  'S0r3': 1,
#  'TusharDhruvabalParab': 1,
#  'zbeng': 3,
#  'PHmaster': 1,
#  'DesquneR': 4,
#  'tig3rhack': 1,
#  'psych0pat': 1,
#  'Kenneth_nap': 2,
#  'jean-claude': 1,
#  'Guelfoweb': 2,
#  'Rapt0r': 3,
#  '0x585353': 1,
#  'hack4011': 1,
#  'KnocKout': 2,
#  'Cheese': 1,
#  's0m.ph': 17,
#  'MIsterC.': 36,
#  'Nubilosus': 2,
#  'Kimzi': 1,
#  'CyberPower': 1,
#  'Jath': 5,
#  'm4d': 1,
#  's-dz': 2,
#  'Ishkur88': 1,
#  'Skunkfoot': 88,
#  'dyd': 1,
#  'Ribel': 25,
#  'UeCr3w': 3,
#  'Rofl': 3,
#  'bonsaiviking': 1,
#  'cLicK2cLicK': 2,
#  'lnxg33k': 1,
#  'shadh0driv3r': 1,
#  'abhisheklyall': 2,
#  'FdumanLi': 1,
#  'SatishKini': 1,
#  'vlad_slick': 1,
#  'EsCaHc': 1,
#  'BluePhreak': 1,
#  'JonStockton': 38,
#  'nuclear': 1,
#  'GhostHacker': 4,
#  'NoRK': 3,
#  'OWNEDHACK.COM': 10,
#  'CyberBellona': 25,
#  'CiZreLi': 1,
#  'Ricky': 3,
#  'WeBisTaN': 5,
#  '1923Turk': 21,
#  'xsd': 1,
#  'kmkz': 1,
#  'BlackMonkey': 1,
#  'SCRiPToRiuM': 98,
#  'GormYa': 1,
#  'PlexTheGod': 1,
#  'CEYHUN': 1,
#  'fluxx': 1,
#  'CiCoSz': 156,
#  'Kollapse': 1,
#  'www.1nj3ct.org': 3,
#  'iNs4n3PT': 1,
#  'panzerturk': 1,
#  'speckien': 1,
#  'SoldierOfAllah': 1,
#  'snoop': 1,
#  'g4ng-sT0r': 14,
#  'army': 4,
#  'wolfrat': 16,
#  'SsAgEnT': 9,
#  'ArhamMuhammad': 27,
#  'FasTWORM': 7,
#  'AnDRei_SeMiH': 1,
#  'Zer0Man': 9,
#  '1NT3RF3R0N': 1,
#  'Th3_Ph4t3': 1,
#  'Wild.D3f4c3r': 21,
#  'Error_Code': 2,
#  'xssworm': 1,
#  'Dream_Team_LFD': 1,
#  'ex0day': 1,
#  'Phenom': 1,
#  'infus3': 2,
#  'PierreCholhot': 1,
#  'Brenn0': 21,
#  'LadyViolet': 4,
#  'kokjj87': 1,
#  'OutL4w': 1,
#  'xsstr': 1,
#  'EdgardChammas': 7,
#  'isoz': 13,
#  'Nilesh': 2,
#  'FlorianS.': 3,
#  ...}
